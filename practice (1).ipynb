# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot
x=[3,4,6,9,11,24,36,43,14,100]
d=np.sort(x)
print(df)
# how to remove the outliers from the data
iqr=36-6
upperfence=36+1.5*(30)
lowerfence=6-1.5*(30)
print(upperfence)
print(lowerfence)
print(np.min(x))
print(np.mean(df))
x.remove(100)
print(x)
x.sort()
print(x)
sns.boxplot(x)# now there is not any outlier is ther now is your data is clean
# Out:
# [  3   4   6   9  11  14  24  36  43 100]
# 81.0
# -39.0
# 3
# 25.0
# [3, 4, 6, 9, 11, 24, 36, 43, 14]
# [3, 4, 6, 9, 11, 14, 24, 36, 43]
# <Axes: >

# %%
import numpy as np
import seaborn as sns

arr= np.array([2,4,6,7,8,9,12,13,16,17,23,25,27,34,37,201])
Q1= np.percentile(arr,25)
Q2 = np.percentile(arr,50)
Q3 = np.percentile(arr,75)

IQR = Q3 - Q1
UF= Q3 + (1.5 * IQR)
LF= Q1 - (1.5 * IQR)

list=[]
for i in arr:
    if i >= LF and i <= UF:
        list.append(i)
        arr2= np.array(list)
sns.boxplot(x= arr)
# Out:
# <Axes: >

# %%
sns.boxplot(x=arr2)
# Out:
# <Axes: >
